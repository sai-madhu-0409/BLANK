# %% [markdown]
# <a href="https://colab.research.google.com/github/sai-madhu-0409/BLANK/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7,8,9]
y=[41,53,46,55,77,88,33,27,99]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='green', marker='+',linestyle=' ')

# %%
plt.plot(x,y,color='green', marker='+',linestyle=' ')
